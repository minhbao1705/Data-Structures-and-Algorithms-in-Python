# %% [markdown]
# Fist we need to look into array because there are some issues with arrays that linked list tries to solve.
#
# Here have an array of stock prices and it this is memmory layout of those stock prices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you wen to insert an element 284 at location number 1 then it will inset 284 at location number 1 and it will swapp all the elements
#
# ![image.png](attachment:image.png)
#
# So the array insertion complexity is 0(n)
#
# If i want to insert 284 at location 1, the way dynamic array is in this situation. These array memory locations, and the one which are grayed out those are allocated to a different program or some different variable in same program so it cannot use this location after 292.
#
# ![image-2.png](attachment:image-2.png)
#
# Hence, it will go into some different area of memory which is a RAM and it will allocate more capacity and then it will copy all these elements one by one.
#
# The way dynamic array works is if the initial capacity is 5 it will allocate additional 5x2 which equal to 10 memory locations.
#
# ![image-3.png](attachment:image-3.png)
#
# Then it will copy all these elements here along with 284 value, so here the overhead is not only swapping the elementt but allocating new memory as well as copying all elements from your old memory are to new memory are so you can see that this is not that efficient.

# %% [markdown]
# # Linked-List

# %% [markdown]
# Imagine you gave a data structure like this, where the individual values are stored in two different areas of memory. This data structure is storing values at random memory locations, but those are linkded by the pointers. The first element has a referenced to the address of next element. Through this links, we can access the next element.
#
# ![image.png](attachment:image.png)
#
# When you want to insert 284 at location number on, it becomes very easy because now we just modifying the links
#
# ![image-2.png](attachment:image-2.png)
#
# When you want to insert element at the beginning the complexity order of 1, and similarly if you want to delete the element at the beginning order of 1. If you want insert or delete elemnt in the end or the middle, the complexity is O(n) because you have to address those elements. This data structure is called linked-list
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Double Linked List
#
# There is another flavor of linked list called doubly linked list where you not only have a link to your next element, you have a link to your previous element as well
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self, data=None, next=None):
        # It has two class members
        # one is data.
        # The second one is next which is a pointer to the next element
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        # A head variable which points to the head of the linked list
        self.head = None
    
    # You already have a head and you want inserting anything in front of it. 
    # You will create a node element and the nex value of that node will be your current head.    
    def insert_at_begining(self, data):
        # taking data value and inserting that at the begining of the linked list
        node = Node(data, self.head)
        # when node is created. You can say that my head now is node.
        self.head = node 
    
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return
        
        itr = self.head
        # if itr.next have some value then i will keep on iterating
        while itr.next:
            itr = itr.next
        # if iter.next is null i will and data at the end.
        itr.next = Node(data, None)
        
    def insert_values(self, data_list):
        # Create a new linked list
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next
            
        return count
    
    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid index")
        
        if index==0:
            self.head = self.head.data
            return
        
        count = 0
        itr = self.head
        while itr:
            if count == index-1:
                itr.next = itr.next.next
                break
            itr = itr.next
            count += 1
            
    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return
        
        count = 0
        itr = self.head
        while itr:
            if count == index-1:
                node = Node(data, itr.next)
                itr.next = node
                break
            
            itr = itr.next
            count += 1

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana", "mango", "grapes", "orange"])
    ll.print()
    ll.insert_at(0, "figs")
    ll.print()
    ll.insert_at(2, "jackfruit")
    ll.print()
# Out:
# banana-->mango-->grapes-->orange-->
# figs-->banana-->mango-->grapes-->orange-->
# figs-->banana-->jackfruit-->mango-->grapes-->orange-->

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. In LinkedList class that we implemented in our tutorial add following two methods,
#
# ```
# def insert_after_value(self, data_after, data_to_insert):
#     # Search for first occurance of data_after value in linked list
#     # Now insert data_to_insert after data_after node
#
# def remove_by_value(self, data):
#     # Remove first node that contains data
# ```
# Now make following calls,
#
# ```
#     ll = LinkedList()
#     ll.insert_values(["banana","mango","grapes","orange"])
#     ll.print()
#     ll.insert_after_value("mango","apple") # insert apple after mango
#     ll.print()
#     ll.remove_by_value("orange") # remove orange from linked list
#     ll.print()
#     ll.remove_by_value("figs")
#     ll.print()
#     ll.remove_by_value("banana")
#     ll.remove_by_value("mango")
#     ll.remove_by_value("apple")
#     ll.remove_by_value("grapes")
#     ll.print()
# ```

# %%
class Node:
    def __init__(self, data=None, next=None):
        # It has two class members
        # one is data.
        # The second one is next which is a pointer to the next element
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        # A head variable which points to the head of the linked list
        self.head = None
    
    # You already have a head and you want inserting anything in front of it. 
    # You will create a node element and the nex value of that node will be your current head.    
    def insert_at_begining(self, data):
        # taking data value and inserting that at the begining of the linked list
        node = Node(data, self.head)
        # when node is created. You can say that my head now is node.
        self.head = node 
    
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return
        
        itr = self.head
        # if itr.next have some value then i will keep on iterating
        while itr.next:
            itr = itr.next
        # if iter.next is null i will and data at the end.
        itr.next = Node(data, None)
        
    def insert_values(self, data_list):
        # Create a new linked list
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count += 1
            itr = itr.next
            
        return count
    
    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid index")
        
        if index==0:
            self.head = self.head.data
            return
        
        count = 0
        itr = self.head
        while itr:
            if count == index-1:
                itr.next = itr.next.next
                break
            itr = itr.next
            count += 1
            
    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return
        
        count = 0
        itr = self.head
        while itr:
            if count == index-1:
                node = Node(data, itr.next)
                itr.next = node
                break
            
            itr = itr.next
            count += 1
            
    def insert_after_value(self, data_after, data_to_insert):
    # Search for first occurance of data_after value in linked list
    # Now insert data_to_insert after data_after node
        if self.head is None:
            raise Exception("Invalid Index")
        
        if self.head.data==data_after:
            self.head.next = Node(data_to_insert, self.head.next)
            return
    
        itr = self.head
        while itr:
            if itr.data == data_after:
                itr.next = Node(data_to_insert, itr.next)
                break
            
            itr = itr.next

    def remove_by_value(self, data):
    # Remove first node that contains data
        if self.head is None:
            raise Exception("Invalid Index")
        
        if self.head.data==data:
            self.head = self.head.next
            return
        
        itr = self.head
        while itr.next:
            if itr.next.data == data:
                itr.next = itr.next.next
                break
            itr = itr.next

if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print()
    ll.insert_after_value("mango","apple") # insert apple after mango
    ll.print()
    ll.remove_by_value("orange")
    ll.print()
    ll.remove_by_value("figs")
    ll.print()
    ll.remove_by_value("banana")
    ll.print()
    ll.remove_by_value("mango")
    ll.remove_by_value("apple")
    ll.remove_by_value("grapes")
    ll.print()
# Out:
# banana-->mango-->grapes-->orange-->
# banana-->mango-->apple-->grapes-->orange-->
# banana-->mango-->apple-->grapes-->
# banana-->mango-->apple-->grapes-->
# mango-->apple-->grapes-->
# Linked list is empty

# %% [markdown]
# 2. Implement doubly linked list. The only difference with regular linked list is that double linked has prev node reference as well. That way you can iterate in forward and backward direction. Your node class will look this this,
#
# ```
# class Node:
#     def __init__(self, data=None, next=None, prev=None):
#         self.data = data
#         self.next = next
#         self.prev = prev
# ```
# Add following new methods,
# ```
# def print_forward(self):
#     # This method prints list in forward direction. Use node.next
#
# def print_backward(self):
#     # Print linked list in reverse direction. Use node.prev for this.
# ```
# Implement all other methods in regular linked list class and make necessary changes for doubly linked list (you need to populate node.prev in all those methods)

# %%
class Node:
    def __init__(self, data=None, next=None, prev=None):
        self.data = data
        self.next = next
        self.prev = prev
        
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        
    def insert_at_begining(self, data):
        if self.head == None:
            node = Node(data, self.head, None)
            self.head = node 
        else:
            node = Node(data, self.head, None)
            self.head.prev = node
            self.head = node
    
    def insert_at_end(self, data):
        if self.head == None:
            self.head = Node(data, None, None)
            return
        
        itr = self.head 
        
        while itr.next:
            itr = itr.next
            
        itr.next = Node(data,None,itr)
    
    def get_last_node(self):
        itr = self.head 
        while itr.next:
            itr = itr.next
        
        return itr
    
    def get_length(self):
        count = 0
        itr = self.head 
        while itr:
            count += 1
            itr = itr.next
        
        return count
    
    def insert_at(self, index, data):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return
        
        count = 0
        itr = self.head 
        while itr:
            if count == index - 1:
                node = Node(data,itr.next, itr)
                if node.next:
                    node.next.prev = node
                itr.next = node
                break
            
            itr = itr.next 
            count += 1
    
    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.head = self.head.next
            self.head.prev = None
            return
        
        count = 0
        itr = self.head 
        while itr:
            if count == index:
                itr.prev.next = itr.next
                if itr.next:
                    itr.next.prev = itr.prev
            count += 1
            itr = itr.next
    
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def print_forward(self):
    # This method prints list in forward direction. Use node.next
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head 
        llstr = ''
        
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next
        print(llstr)

    def print_backward(self):
    # Print linked list in reverse direction. Use node.prev for this.\
        if self.head is None:
            print("Linked list is empty")
            return
        
        last_node = self.get_last_node()
        itr = last_node
        llstr = ''
        while itr:
            llstr += itr.data + '-->'
            itr = itr.prev 
        print("Link list in reverse: ", llstr)
        
if __name__ == '__main__':
    ll = DoublyLinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print_forward()
    ll.print_backward()
    ll.insert_at_end("figs")
    ll.print_forward()
    ll.insert_at(0,"jackfruit")
    ll.print_forward()
    ll.insert_at(4,"dates")
    ll.print_forward()
    ll.insert_at(2,"kiwi")
    ll.print_forward()
# Out:
# banana-->mango-->grapes-->orange-->
# Link list in reverse:  orange-->grapes-->mango-->banana-->
# banana-->mango-->grapes-->orange-->figs-->
# jackfruit-->banana-->mango-->grapes-->orange-->figs-->
# jackfruit-->banana-->mango-->grapes-->dates-->orange-->figs-->
# jackfruit-->banana-->kiwi-->mango-->grapes-->dates-->orange-->figs-->
